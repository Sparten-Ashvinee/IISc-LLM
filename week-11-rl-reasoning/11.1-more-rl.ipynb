# %% [markdown]
# # 11.1 – More RL
#
# > **Course**: Large Language Models – A Hands-on Approach
# > **Website**: [llm-engg.github.io](https://llm-engg.github.io/)

# %% [markdown]
# ## Overview
#
# Go deeper into reinforcement learning for LLMs: GRPO, REINFORCE, and Group Relative Policy Optimization as used in DeepSeek-R1.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# - Understand REINFORCE and its application to LLM training
# - Explore GRPO (Group Relative Policy Optimization)
# - Understand how DeepSeek-R1 used RL for reasoning
# - Implement a simple reward function for code generation

# %% [markdown]
# ## Setup

# %%
# Install required packages (uncomment as needed)
# !pip install -q transformers datasets accelerate torch

# %%
import os
import torch

print(f'PyTorch version: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')

# %% [markdown]
# ## 1. Understand REINFORCE and its application to LLM training

# %%
# TODO: Implement Understand REINFORCE and its application to LLM training

# %% [markdown]
# ## 2. Explore GRPO (Group Relative Policy Optimization)

# %%
# TODO: Implement Explore GRPO (Group Relative Policy Optimization)

# %% [markdown]
# ## 3. Understand how DeepSeek-R1 used RL for reasoning

# %%
# TODO: Implement Understand how DeepSeek-R1 used RL for reasoning

# %% [markdown]
# ## 4. Implement a simple reward function for code generation

# %%
# TODO: Implement Implement a simple reward function for code generation

# %% [markdown]
# ## Exercises
#
# 1. Complete the TODO sections above.
# 2. Experiment with the parameters and observe the effects.
# 3. Document your findings.

# %% [markdown]
# ## Resources
#
# - [Course Website](https://llm-engg.github.io/)
# - [Hugging Face Documentation](https://huggingface.co/docs)
