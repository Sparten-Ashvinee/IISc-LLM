# %% [markdown]
# # 7.1 – RAG Fundamentals – Context Engineering, Embeddings, Search and Rerankers
#
# > **Course**: Large Language Models – A Hands-on Approach
# > **Website**: [llm-engg.github.io](https://llm-engg.github.io/)

# %% [markdown]
# ## Overview
#
# Build a Retrieval-Augmented Generation pipeline from scratch, covering embedding models, vector databases, and rerankers.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# - Build a basic RAG pipeline with FAISS vector store
# - Use sentence-transformers for dense retrieval
# - Implement BM25 sparse retrieval and compare with dense
# - Add a cross-encoder reranker to improve result quality

# %% [markdown]
# ## Setup

# %%
# Install required packages (uncomment as needed)
# !pip install -q transformers datasets accelerate torch

# %%
import os
import torch

print(f'PyTorch version: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')

# %% [markdown]
# ## 1. Build a basic RAG pipeline with FAISS vector store

# %%
# TODO: Implement Build a basic RAG pipeline with FAISS vector store

# %% [markdown]
# ## 2. Use sentence-transformers for dense retrieval

# %%
# TODO: Implement Use sentence-transformers for dense retrieval

# %% [markdown]
# ## 3. Implement BM25 sparse retrieval and compare with dense

# %%
# TODO: Implement Implement BM25 sparse retrieval and compare with dense

# %% [markdown]
# ## 4. Add a cross-encoder reranker to improve result quality

# %%
# TODO: Implement Add a cross-encoder reranker to improve result quality

# %% [markdown]
# ## Exercises
#
# 1. Complete the TODO sections above.
# 2. Experiment with the parameters and observe the effects.
# 3. Document your findings.

# %% [markdown]
# ## Resources
#
# - [Course Website](https://llm-engg.github.io/)
# - [Hugging Face Documentation](https://huggingface.co/docs)
