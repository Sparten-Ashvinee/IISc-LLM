# %% [markdown]
# # 10.1 – Instruction Tuning
#
# > **Course**: Large Language Models – A Hands-on Approach
# > **Website**: [llm-engg.github.io](https://llm-engg.github.io/)

# %% [markdown]
# ## Overview
#
# Learn how instruction tuning transforms a base language model into a helpful assistant by training on instruction-response pairs.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# - Understand the difference between base models and instruction-tuned models
# - Prepare an instruction-following dataset from existing sources
# - Fine-tune a model using SFTTrainer with LoRA/QLoRA
# - Evaluate the instruction-following quality of the fine-tuned model

# %% [markdown]
# ## Setup

# %%
# Install required packages (uncomment as needed)
# !pip install -q transformers datasets accelerate torch

# %%
import os
import torch

print(f'PyTorch version: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')

# %% [markdown]
# ## 1. Understand the difference between base models and instruction-tuned models

# %%
# TODO: Implement Understand the difference between base models and instruction-tuned models

# %% [markdown]
# ## 2. Prepare an instruction-following dataset from existing sources

# %%
# TODO: Implement Prepare an instruction-following dataset from existing sources

# %% [markdown]
# ## 3. Fine-tune a model using SFTTrainer with LoRA/QLoRA

# %%
# TODO: Implement Fine-tune a model using SFTTrainer with LoRA/QLoRA

# %% [markdown]
# ## 4. Evaluate the instruction-following quality of the fine-tuned model

# %%
# TODO: Implement Evaluate the instruction-following quality of the fine-tuned model

# %% [markdown]
# ## Exercises
#
# 1. Complete the TODO sections above.
# 2. Experiment with the parameters and observe the effects.
# 3. Document your findings.

# %% [markdown]
# ## Resources
#
# - [Course Website](https://llm-engg.github.io/)
# - [Hugging Face Documentation](https://huggingface.co/docs)
