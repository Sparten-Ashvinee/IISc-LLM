# %% [markdown]
# # 1.1 – Orientation & Transformer Architecture
#
# > **Course**: Large Language Models – A Hands-on Approach
# > **Website**: [llm-engg.github.io](https://llm-engg.github.io/)

# %% [markdown]
# ## Overview
#
# Introduction to the course and deep dive into transformer architecture, the backbone of modern LLMs.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# - Explain the transformer architecture and its key components
# - Implement scaled dot-product attention from scratch
# - Understand positional encoding and why it matters
# - Trace the data flow through a transformer encoder/decoder

# %% [markdown]
# ## Setup

# %%
# Install required packages (uncomment as needed)
# !pip install -q transformers datasets accelerate torch

# %%
import os
import torch

print(f'PyTorch version: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')

# %% [markdown]
# ## 1. Explain the transformer architecture and its key components

# %%
# TODO: Implement Explain the transformer architecture and its key components

# %% [markdown]
# ## 2. Implement scaled dot-product attention from scratch

# %%
# TODO: Implement Implement scaled dot-product attention from scratch

# %% [markdown]
# ## 3. Understand positional encoding and why it matters

# %%
# TODO: Implement Understand positional encoding and why it matters

# %% [markdown]
# ## 4. Trace the data flow through a transformer encoder/decoder

# %%
# TODO: Implement Trace the data flow through a transformer encoder/decoder

# %% [markdown]
# ## Exercises
#
# 1. Complete the TODO sections above.
# 2. Experiment with the parameters and observe the effects.
# 3. Document your findings.

# %% [markdown]
# ## Resources
#
# - [Course Website](https://llm-engg.github.io/)
# - [Hugging Face Documentation](https://huggingface.co/docs)
