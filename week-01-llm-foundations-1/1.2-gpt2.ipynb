# %% [markdown]
# # 1.2 – GPT-2
#
# > **Course**: Large Language Models – A Hands-on Approach
# > **Website**: [llm-engg.github.io](https://llm-engg.github.io/)

# %% [markdown]
# ## Overview
#
# Explore GPT-2 architecture and understand how autoregressive language models are trained and used for text generation.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# - Understand the GPT-2 architecture and its differences from BERT
# - Load and run GPT-2 using Hugging Face Transformers
# - Implement basic text generation with top-k and nucleus sampling
# - Inspect model weights and attention patterns

# %% [markdown]
# ## Setup

# %%
# Install required packages (uncomment as needed)
# !pip install -q transformers datasets accelerate torch

# %%
import os
import torch

print(f'PyTorch version: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')

# %% [markdown]
# ## 1. Understand the GPT-2 architecture and its differences from BERT

# %%
# TODO: Implement Understand the GPT-2 architecture and its differences from BERT

# %% [markdown]
# ## 2. Load and run GPT-2 using Hugging Face Transformers

# %%
# TODO: Implement Load and run GPT-2 using Hugging Face Transformers

# %% [markdown]
# ## 3. Implement basic text generation with top-k and nucleus sampling

# %%
# TODO: Implement Implement basic text generation with top-k and nucleus sampling

# %% [markdown]
# ## 4. Inspect model weights and attention patterns

# %%
# TODO: Implement Inspect model weights and attention patterns

# %% [markdown]
# ## Exercises
#
# 1. Complete the TODO sections above.
# 2. Experiment with the parameters and observe the effects.
# 3. Document your findings.

# %% [markdown]
# ## Resources
#
# - [Course Website](https://llm-engg.github.io/)
# - [Hugging Face Documentation](https://huggingface.co/docs)
