# %% [markdown]
# # 4.2 – Inference Math and Bottlenecks
#
# > **Course**: Large Language Models – A Hands-on Approach
# > **Website**: [llm-engg.github.io](https://llm-engg.github.io/)

# %% [markdown]
# ## Overview
#
# Analyze the arithmetic intensity of LLM inference and identify the key bottlenecks: memory bandwidth vs compute.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# - Calculate FLOPs for a transformer forward pass
# - Derive memory bandwidth requirements for autoregressive inference
# - Identify the roofline model and where LLMs operate
# - Understand prefill vs decode phase differences

# %% [markdown]
# ## Setup

# %%
# Install required packages (uncomment as needed)
# !pip install -q transformers datasets accelerate torch

# %%
import os
import torch

print(f'PyTorch version: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')

# %% [markdown]
# ## 1. Calculate FLOPs for a transformer forward pass

# %%
# TODO: Implement Calculate FLOPs for a transformer forward pass

# %% [markdown]
# ## 2. Derive memory bandwidth requirements for autoregressive inference

# %%
# TODO: Implement Derive memory bandwidth requirements for autoregressive inference

# %% [markdown]
# ## 3. Identify the roofline model and where LLMs operate

# %%
# TODO: Implement Identify the roofline model and where LLMs operate

# %% [markdown]
# ## 4. Understand prefill vs decode phase differences

# %%
# TODO: Implement Understand prefill vs decode phase differences

# %% [markdown]
# ## Exercises
#
# 1. Complete the TODO sections above.
# 2. Experiment with the parameters and observe the effects.
# 3. Document your findings.

# %% [markdown]
# ## Resources
#
# - [Course Website](https://llm-engg.github.io/)
# - [Hugging Face Documentation](https://huggingface.co/docs)
