# %% [markdown]
# # 6.1 – Inference Engines and Multi GPU
#
# > **Course**: Large Language Models – A Hands-on Approach
# > **Website**: [llm-engg.github.io](https://llm-engg.github.io/)

# %% [markdown]
# ## Overview
#
# Deploy and benchmark production inference engines including vLLM and HuggingFace TGI for high-throughput serving.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# - Serve a model using vLLM and benchmark throughput
# - Compare vLLM vs Hugging Face TGI on the same model
# - Use tensor parallelism in vLLM for multi-GPU serving
# - Implement continuous batching and understand its advantages

# %% [markdown]
# ## Setup

# %%
# Install required packages (uncomment as needed)
# !pip install -q transformers datasets accelerate torch

# %%
import os
import torch

print(f'PyTorch version: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')

# %% [markdown]
# ## 1. Serve a model using vLLM and benchmark throughput

# %%
# TODO: Implement Serve a model using vLLM and benchmark throughput

# %% [markdown]
# ## 2. Compare vLLM vs Hugging Face TGI on the same model

# %%
# TODO: Implement Compare vLLM vs Hugging Face TGI on the same model

# %% [markdown]
# ## 3. Use tensor parallelism in vLLM for multi-GPU serving

# %%
# TODO: Implement Use tensor parallelism in vLLM for multi-GPU serving

# %% [markdown]
# ## 4. Implement continuous batching and understand its advantages

# %%
# TODO: Implement Implement continuous batching and understand its advantages

# %% [markdown]
# ## Exercises
#
# 1. Complete the TODO sections above.
# 2. Experiment with the parameters and observe the effects.
# 3. Document your findings.

# %% [markdown]
# ## Resources
#
# - [Course Website](https://llm-engg.github.io/)
# - [Hugging Face Documentation](https://huggingface.co/docs)
