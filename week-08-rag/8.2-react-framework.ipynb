# %% [markdown]
# # 8.2 – ReAct Framework: Thought → Action → Observation
#
# > **Course**: Large Language Models – A Hands-on Approach
# > **Website**: [llm-engg.github.io](https://llm-engg.github.io/)

# %% [markdown]
# ## Overview
#
# Implement the ReAct (Reasoning + Acting) framework for building tool-augmented LLM agents.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# - Understand the ReAct prompting framework and its loop
# - Implement a ReAct agent with tool use from scratch
# - Integrate web search and calculator tools into an agent
# - Trace thought-action-observation chains and debug failures

# %% [markdown]
# ## Setup

# %%
# Install required packages (uncomment as needed)
# !pip install -q transformers datasets accelerate torch

# %%
import os
import torch

print(f'PyTorch version: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')

# %% [markdown]
# ## 1. Understand the ReAct prompting framework and its loop

# %%
# TODO: Implement Understand the ReAct prompting framework and its loop

# %% [markdown]
# ## 2. Implement a ReAct agent with tool use from scratch

# %%
# TODO: Implement Implement a ReAct agent with tool use from scratch

# %% [markdown]
# ## 3. Integrate web search and calculator tools into an agent

# %%
# TODO: Implement Integrate web search and calculator tools into an agent

# %% [markdown]
# ## 4. Trace thought-action-observation chains and debug failures

# %%
# TODO: Implement Trace thought-action-observation chains and debug failures

# %% [markdown]
# ## Exercises
#
# 1. Complete the TODO sections above.
# 2. Experiment with the parameters and observe the effects.
# 3. Document your findings.

# %% [markdown]
# ## Resources
#
# - [Course Website](https://llm-engg.github.io/)
# - [Hugging Face Documentation](https://huggingface.co/docs)
