# %% [markdown]
# # 8.1 – Evaluating RAG
#
# > **Course**: Large Language Models – A Hands-on Approach
# > **Website**: [llm-engg.github.io](https://llm-engg.github.io/)

# %% [markdown]
# ## Overview
#
# Evaluate RAG systems using RAGAS metrics including faithfulness, answer relevancy, and context recall.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# - Understand key RAG evaluation metrics: faithfulness, relevancy, recall
# - Use RAGAS to evaluate a RAG pipeline end-to-end
# - Identify common RAG failure modes and how to diagnose them
# - Build an LLM-as-a-judge evaluation pipeline

# %% [markdown]
# ## Setup

# %%
# Install required packages (uncomment as needed)
# !pip install -q transformers datasets accelerate torch

# %%
import os
import torch

print(f'PyTorch version: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')

# %% [markdown]
# ## 1. Understand key RAG evaluation metrics: faithfulness, relevancy, recall

# %%
# TODO: Implement Understand key RAG evaluation metrics: faithfulness, relevancy, recall

# %% [markdown]
# ## 2. Use RAGAS to evaluate a RAG pipeline end-to-end

# %%
# TODO: Implement Use RAGAS to evaluate a RAG pipeline end-to-end

# %% [markdown]
# ## 3. Identify common RAG failure modes and how to diagnose them

# %%
# TODO: Implement Identify common RAG failure modes and how to diagnose them

# %% [markdown]
# ## 4. Build an LLM-as-a-judge evaluation pipeline

# %%
# TODO: Implement Build an LLM-as-a-judge evaluation pipeline

# %% [markdown]
# ## Exercises
#
# 1. Complete the TODO sections above.
# 2. Experiment with the parameters and observe the effects.
# 3. Document your findings.

# %% [markdown]
# ## Resources
#
# - [Course Website](https://llm-engg.github.io/)
# - [Hugging Face Documentation](https://huggingface.co/docs)
