# %% [markdown]
# # 5.1 – Efficient Attention & KV Caching
#
# > **Course**: Large Language Models – A Hands-on Approach
# > **Website**: [llm-engg.github.io](https://llm-engg.github.io/)

# %% [markdown]
# ## Overview
#
# Learn how KV caching accelerates autoregressive inference and explore Flash Attention for memory-efficient computation.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# - Implement KV cache for autoregressive generation
# - Measure the speedup from KV caching in practice
# - Understand Flash Attention and its memory complexity
# - Explore paged attention as used in vLLM

# %% [markdown]
# ## Setup

# %%
# Install required packages (uncomment as needed)
# !pip install -q transformers datasets accelerate torch

# %%
import os
import torch

print(f'PyTorch version: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')

# %% [markdown]
# ## 1. Implement KV cache for autoregressive generation

# %%
# TODO: Implement Implement KV cache for autoregressive generation

# %% [markdown]
# ## 2. Measure the speedup from KV caching in practice

# %%
# TODO: Implement Measure the speedup from KV caching in practice

# %% [markdown]
# ## 3. Understand Flash Attention and its memory complexity

# %%
# TODO: Implement Understand Flash Attention and its memory complexity

# %% [markdown]
# ## 4. Explore paged attention as used in vLLM

# %%
# TODO: Implement Explore paged attention as used in vLLM

# %% [markdown]
# ## Exercises
#
# 1. Complete the TODO sections above.
# 2. Experiment with the parameters and observe the effects.
# 3. Document your findings.

# %% [markdown]
# ## Resources
#
# - [Course Website](https://llm-engg.github.io/)
# - [Hugging Face Documentation](https://huggingface.co/docs)
