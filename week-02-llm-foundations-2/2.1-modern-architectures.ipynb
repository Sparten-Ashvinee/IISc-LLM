# %% [markdown]
# # 2.1 – Modern Architectures
#
# > **Course**: Large Language Models – A Hands-on Approach
# > **Website**: [llm-engg.github.io](https://llm-engg.github.io/)

# %% [markdown]
# ## Overview
#
# Survey of modern LLM architectures including LLaMA, Mistral, Qwen, and Gemma – their design choices and improvements over GPT.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# - Compare architectural differences between LLaMA, Mistral, Qwen, and Gemma
# - Understand RoPE (Rotary Positional Embedding) and its advantages
# - Explore Grouped Query Attention (GQA) and Multi-Query Attention (MQA)
# - Analyze the role of RMSNorm vs LayerNorm

# %% [markdown]
# ## Setup

# %%
# Install required packages (uncomment as needed)
# !pip install -q transformers datasets accelerate torch

# %%
import os
import torch

print(f'PyTorch version: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')

# %% [markdown]
# ## 1. Compare architectural differences between LLaMA, Mistral, Qwen, and Gemma

# %%
# TODO: Implement Compare architectural differences between LLaMA, Mistral, Qwen, and Gemma

# %% [markdown]
# ## 2. Understand RoPE (Rotary Positional Embedding) and its advantages

# %%
# TODO: Implement Understand RoPE (Rotary Positional Embedding) and its advantages

# %% [markdown]
# ## 3. Explore Grouped Query Attention (GQA) and Multi-Query Attention (MQA)

# %%
# TODO: Implement Explore Grouped Query Attention (GQA) and Multi-Query Attention (MQA)

# %% [markdown]
# ## 4. Analyze the role of RMSNorm vs LayerNorm

# %%
# TODO: Implement Analyze the role of RMSNorm vs LayerNorm

# %% [markdown]
# ## Exercises
#
# 1. Complete the TODO sections above.
# 2. Experiment with the parameters and observe the effects.
# 3. Document your findings.

# %% [markdown]
# ## Resources
#
# - [Course Website](https://llm-engg.github.io/)
# - [Hugging Face Documentation](https://huggingface.co/docs)
