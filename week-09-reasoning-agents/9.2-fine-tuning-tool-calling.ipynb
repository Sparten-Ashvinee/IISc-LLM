# %% [markdown]
# # 9.2 – Fine Tuning for Tool Calling
#
# > **Course**: Large Language Models – A Hands-on Approach
# > **Website**: [llm-engg.github.io](https://llm-engg.github.io/)

# %% [markdown]
# ## Overview
#
# Fine-tune a small LLM specifically for tool/function calling using supervised fine-tuning on tool-call datasets.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# - Prepare a dataset in tool-calling chat format
# - Fine-tune a model with SFT using TRL's SFTTrainer
# - Evaluate improvement in tool-calling accuracy
# - Understand the data format for function-calling instruction tuning

# %% [markdown]
# ## Setup

# %%
# Install required packages (uncomment as needed)
# !pip install -q transformers datasets accelerate torch

# %%
import os
import torch

print(f'PyTorch version: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')

# %% [markdown]
# ## 1. Prepare a dataset in tool-calling chat format

# %%
# TODO: Implement Prepare a dataset in tool-calling chat format

# %% [markdown]
# ## 2. Fine-tune a model with SFT using TRL's SFTTrainer

# %%
# TODO: Implement Fine-tune a model with SFT using TRL's SFTTrainer

# %% [markdown]
# ## 3. Evaluate improvement in tool-calling accuracy

# %%
# TODO: Implement Evaluate improvement in tool-calling accuracy

# %% [markdown]
# ## 4. Understand the data format for function-calling instruction tuning

# %%
# TODO: Implement Understand the data format for function-calling instruction tuning

# %% [markdown]
# ## Exercises
#
# 1. Complete the TODO sections above.
# 2. Experiment with the parameters and observe the effects.
# 3. Document your findings.

# %% [markdown]
# ## Resources
#
# - [Course Website](https://llm-engg.github.io/)
# - [Hugging Face Documentation](https://huggingface.co/docs)
