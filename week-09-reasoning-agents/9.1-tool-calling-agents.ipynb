# %% [markdown]
# # 9.1 – Tool Calling, Agents
#
# > **Course**: Large Language Models – A Hands-on Approach
# > **Website**: [llm-engg.github.io](https://llm-engg.github.io/)

# %% [markdown]
# ## Overview
#
# Build function-calling agents using modern LLM APIs and understand how tool schemas are defined and parsed.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# - Define tool schemas using JSON Schema format
# - Build an agent that selects and calls tools based on user input
# - Handle multi-turn tool-calling conversations
# - Evaluate agent accuracy on tool-calling benchmarks

# %% [markdown]
# ## Setup

# %%
# Install required packages (uncomment as needed)
# !pip install -q transformers datasets accelerate torch

# %%
import os
import torch

print(f'PyTorch version: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')

# %% [markdown]
# ## 1. Define tool schemas using JSON Schema format

# %%
# TODO: Implement Define tool schemas using JSON Schema format

# %% [markdown]
# ## 2. Build an agent that selects and calls tools based on user input

# %%
# TODO: Implement Build an agent that selects and calls tools based on user input

# %% [markdown]
# ## 3. Handle multi-turn tool-calling conversations

# %%
# TODO: Implement Handle multi-turn tool-calling conversations

# %% [markdown]
# ## 4. Evaluate agent accuracy on tool-calling benchmarks

# %%
# TODO: Implement Evaluate agent accuracy on tool-calling benchmarks

# %% [markdown]
# ## Exercises
#
# 1. Complete the TODO sections above.
# 2. Experiment with the parameters and observe the effects.
# 3. Document your findings.

# %% [markdown]
# ## Resources
#
# - [Course Website](https://llm-engg.github.io/)
# - [Hugging Face Documentation](https://huggingface.co/docs)
